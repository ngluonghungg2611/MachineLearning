# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame

# %% [markdown]
# # **Line**

# %%
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2017, 1, 11)

# %%
df = web.DataReader("AAPL", 'yahoo', start, end)
df.tail()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-01-05  29.215000  28.952499  28.980000  29.152500   88774400.0  27.521944
# 2017-01-06  29.540001  29.117500  29.195000  29.477501  127007600.0  27.828764
# 2017-01-09  29.857500  29.485001  29.487499  29.747499  134247600.0  28.083660
# 2017-01-10  29.844999  29.575001  29.692499  29.777500   97848400.0  28.111979
# 2017-01-11  29.982500  29.650000  29.684999  29.937500  110354400.0  28.263029

# %%
plt.plot(df['Close'].tail(50), linestyle='-', marker='s', color = 'red')
plt.ylabel('Gia chung khoan')
plt.xlabel('Thoi gian')
plt.title('Gia chung khoan APPLE')
# Out:
# Text(0.5, 1.0, 'Gia chung khoan APPLE')

# %%
df['Close'].tail(25).plot(marker = 's')

# %% [markdown]
# # **Barchart**

# %%
plt.bar(x = ['Nhóm A', 'nhóm B', 'nhóm C'], height=[10,20,50], color = ['red','green','blue'])
plt.xlabel('Tên các nhóm')
plt.ylabel('Giá trị của các nhóm')
# Out:
# Text(0, 0.5, 'Giá trị của các nhóm')

# %% [markdown]
# # **Pie**

# %%
plt.pie(x=np.array([10,20,50]), #Giá trị của các nhóm
        labels = ['Nhóm A', 'Nhóm B', 'Nhóm C'], #Nhãn của các nhóm
        colors = ['red','green','blue'], #Màu sắc
        autopct = '%1.1f%%', #Fomat hiển thị giá trị %
        shadow = True #Đổ bóng
        )
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3a8e434090>,
#   <matplotlib.patches.Wedge at 0x7f3a8e434610>,
#   <matplotlib.patches.Wedge at 0x7f3a8e3dec50>],
#  [Text(1.0162674857624154, 0.4209517756015988, 'Nhóm A'),
#   Text(6.735557395310444e-17, 1.1, 'Nhóm B'),
#   Text(-0.4209517756015994, -1.0162674857624152, 'Nhóm C')],
#  [Text(0.5543277195067721, 0.22961005941905385, '12.5%'),
#   Text(3.6739403974420595e-17, 0.6, '25.0%'),
#   Text(-0.22961005941905419, -0.5543277195067718, '62.5%')])

# %% [markdown]
# # **Boxplot**
# *Biểu đồ boxplot sẽ cho ta biết đặc trưng về phân phối của 1 biến dựa trên các giá trị trung bình, min, max, các khoảng phân vị 25%, 50%, 75%. Đây là biểu đồ được sử dụng nhiều trong chứng khoán và thống kê học để so sánh các biến với nhau.*

# %%
x = np.random.randn(100) + np.arange(0,100)*0.5
y = np.random.randn(100) + np.arange(0,100)*1.0 + 10
z = np.random.randn(100) + np.arange(0,100)*2 - 15

# %%
plt.boxplot([x,y,z], labels = ['x','y','z'], showfliers = True)
plt.title('ABieeur đồ boxplot')
plt.xlabel('Tên nhóm')
plt.ylabel('Giá trị nhóm')
# Out:
# Text(0, 0.5, 'Giá trị nhóm')

# %% [markdown]
# # **Vẽ biểu đồ trên DataFrame**

# %%
df = web.DataReader(["AAPL", "GOOGL", "MSFT", "FB"], 'yahoo', start, end)
df = df[['Close']]
df.tail()
# Out:
# Attributes      Close
# Symbols          AAPL       GOOGL       MSFT          FB
# Date
# 2017-01-05  29.152500  813.020020  62.299999  120.669998
# 2017-01-06  29.477501  825.210022  62.840000  123.410004
# 2017-01-09  29.747499  827.179993  62.639999  124.900002
# 2017-01-10  29.777500  826.010010  62.619999  124.349998
# 2017-01-11  29.937500  829.859985  63.189999  126.089996

# %%
df.plot()

# %%
df.tail(20).plot(linestyle = '-.', marker = 'o')

# %%
df.tail(3).plot.bar()

# %%
df.iloc[-1,:].plot.pie(autopct= '%.2f%%')
plt.title('Biểu đồ tròn')
# Out:
# Text(0.5, 1.0, 'Biểu đồ tròn')

# %%
df.plot.area()
